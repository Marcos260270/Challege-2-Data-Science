# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import json

# Ruta al archivo (ajusta si es necesario)
file_path = "TelecomX_Data.json"

# Cargar los datos desde el JSON
with open(file_path, 'r') as f:
    data = json.load(f)

# Convertir a DataFrame
df = pd.json_normalize(data)

# Ver las primeras filas
#print(df.head())
df.head(10)
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
# 5  0013-MHZWF    No          Female                       0               No
# 6  0013-SMEOE    No          Female                       1              Yes
# 7  0014-BMAQU    No            Male                       0              Yes
# 8  0015-UOCOJ    No          Female                       1               No
# 9  0016-QLJIS    No          Female                       0              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# ...

# %%
df.dtypes
# Out:
# customerID                    object
# Churn                         object
# customer.gender               object
# customer.SeniorCitizen         int64
# customer.Partner              object
# customer.Dependents           object
# customer.tenure                int64
# phone.PhoneService            object
# phone.MultipleLines           object
# internet.InternetService      object
# internet.OnlineSecurity       object
# internet.OnlineBackup         object
# internet.DeviceProtection     object
# internet.TechSupport          object
# internet.StreamingTV          object
# internet.StreamingMovies      object
# account.Contract              object
# account.PaperlessBilling      object
# account.PaymentMethod         object
# account.Charges.Monthly      float64
# account.Charges.Total         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
#Convierte el campo account.Charges.Total, a numerico
import numpy as np
df['account.Charges.Total'] = df['account.Charges.Total'].replace(" ", np.nan)
df['account.Charges.Total'] = pd.to_numeric(df['account.Charges.Total'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
df
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
#Se crea una nueva columna con el cargo dario
df['cargo_diario'] = (df['account.Charges.Monthly'] / 30).round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
# Permite identificar los valores unico en cada columna
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Columna: {column}")
    print(f"Valores únicos ({len(unique_values)}): {unique_values}")
    print("-" * 50)
# Out:
# Columna: customerID
# Valores únicos (7267): ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# --------------------------------------------------
# Columna: Churn
# Valores únicos (3): ['No' 'Yes' '']
# --------------------------------------------------
# Columna: customer.gender
# Valores únicos (2): ['Female' 'Male']
# --------------------------------------------------
# Columna: customer.SeniorCitizen
# Valores únicos (2): [0 1]
# --------------------------------------------------
# Columna: customer.Partner
# Valores únicos (2): ['Yes' 'No']
# --------------------------------------------------
# Columna: customer.Dependents
# Valores únicos (2): ['Yes' 'No']
# --------------------------------------------------
# Columna: customer.tenure
# Valores únicos (73): [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
# ...

# %%
#Consulta los registros
df[df['Churn'] == '']
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 30    0047-ZHDTW                Female                       0
# 75    0120-YZLQA                  Male                       0
# 96    0154-QYHJU                  Male                       0
# 98    0162-RZGMZ                Female                       1
# 175   0274-VVQOQ                  Male                       1
# ...          ...   ...             ...                     ...
# 7158  9840-GSRFX                Female                       0
# 7180  9872-RZQQB                Female                       0
# 7211  9920-GNDMB                  Male                       0
# 7239  9955-RVWSC                Female                       0
# 7247  9966-VYRTZ                Female                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 30                 No                  No               11                Yes
# ...

# %%
cantidad_churn = df[df['Churn'] == ''].shape[0]
print(cantidad_churn)
# Out:
# 224

# %%
#seleccionar columnas a limpiar
columnas_a_limpieza = [
    'Churn',
    'customer.gender',
    'customer.Partner',
    'customer.Dependents',
    'phone.PhoneService',
    'internet.InternetService'
]

#Elimina registros con cadenas vacías o solo espacios en esas columnas

# Quitar espacios en blanco y filtrar filas vacías en esas columnas
for col in columnas_a_limpieza:
    df = df[df[col].str.strip() != '']

#Quitar también los valores nulos (NaN)
df = df.dropna(subset=columnas_a_limpieza)

#Normaliza los strings (todo en minúsculas, sin espacios)
for col in columnas_a_limpieza:
    df[col] = df[col].str.strip().str.lower()

# %%
df
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    no          female                       0
# 1     0003-MKNFE    no            male                       0
# 2     0004-TLHLJ   yes            male                       0
# 3     0011-IGKFF   yes            male                       1
# 4     0013-EXCHZ   yes          female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    no          female                       0
# 7263  9992-RRAMN   yes            male                       0
# 7264  9992-UJOEL    no            male                       0
# 7265  9993-LHIEB    no            male                       0
# 7266  9995-HOTOH    no            male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 yes                 yes                9                yes
# ...

# %%
#Grafico con matplotlib

import matplotlib.pyplot as plt

# Conteo de valores
churn_counts = df['Churn'].value_counts()

# Gráfico de barras
plt.figure(figsize=(6,4))
churn_counts.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Distribución de la variable Churn')
plt.xlabel('Churn')
plt.ylabel('Cantidad de clientes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#Grafica con seaborn
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Churn', palette='pastel')
plt.title('Distribución de la variable Churn')
plt.xlabel('Churn')
plt.ylabel('Cantidad de clientes')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-2817194952>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Churn', palette='pastel')

# %%
#Pie chart con matplotlib

import matplotlib.pyplot as plt

# Conteo de valores
churn_counts = df['Churn'].value_counts()

# Gráfico de torta
plt.figure(figsize=(6,6))
plt.pie(
    churn_counts,
    labels=churn_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['skyblue', 'salmon'],
    explode=(0, 0.1)  # resalta un sector (por ejemplo, 'Yes')
)
plt.title('Distribución porcentual de Churn')
plt.axis('equal')  # Asegura que el círculo sea redondo
plt.show()

# %%
#Pie chart con seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Estilo de Seaborn
sns.set_theme(style='whitegrid')

# Datos
churn_counts = df['Churn'].value_counts()

# Gráfico
plt.figure(figsize=(6,6))
plt.pie(
    churn_counts,
    labels=churn_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=sns.color_palette('pastel')[0:2],
    explode=(0, 0.1)
)
plt.title('Distribución de Churn (estilo Seaborn)')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Tabla cruzada: conteo de Churn por género
churn_genero = pd.crosstab(df['customer.gender'], df['Churn'])

# Gráfico de barras apiladas
churn_genero.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'], figsize=(8,5))
plt.title('Distribución de Churn según Género')
plt.xlabel('Género')
plt.ylabel('Cantidad de clientes')
plt.legend(title='Churn')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#        customer.SeniorCitizen  customer.tenure  account.Charges.Monthly  \
# count             7043.000000      7043.000000              7043.000000
# mean                 0.162147        32.371149                64.761692
# std                  0.368612        24.559481                30.090047
# min                  0.000000         0.000000                18.250000
# 25%                  0.000000         9.000000                35.500000
# 50%                  0.000000        29.000000                70.350000
# 75%                  0.000000        55.000000                89.850000
# max                  1.000000        72.000000               118.750000
#
#        account.Charges.Total  cargo_diario
# count            7032.000000   7043.000000
# mean             2283.300441      2.158675
# std              2266.771362      1.003088
# min                18.800000      0.610000
# 25%               401.450000      1.180000
# 50%              1397.475000      2.340000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filtramos los clientes que se dieron de baja
df_churn = df[df['Churn'] == 'yes']  # o 'Yes' si no normalizaste

# Contamos por género
churn_por_genero = df_churn['customer.gender'].value_counts()

# Graficamos
plt.figure(figsize=(6,6))
plt.pie(
    churn_por_genero,
    labels=churn_por_genero.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=sns.color_palette('pastel')[0:2],
    explode=(0.05,) * len(churn_por_genero)
)
plt.title('Distribución del Churn por Género')
plt.axis('equal')  # Círculo perfecto
plt.show()

# %%
# Evasión por la variable genero y cantidad
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar solo los clientes que hicieron churn
df_churn = df[df['Churn'] == 'yes']  # Asegúrate que sea 'yes' o 'Yes' según tu dataset

# Contar cuántos churn por género
churn_por_genero = df_churn['customer.gender'].value_counts()

# Función para mostrar porcentaje + cantidad
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({count})'
    return my_autopct

# Gráfico de torta
plt.figure(figsize=(6,6))
plt.pie(
    churn_por_genero,
    labels=churn_por_genero.index,
    autopct=make_autopct(churn_por_genero),
    startangle=90,
    colors=sns.color_palette('pastel')[0:2],
    explode=(0.05,) * len(churn_por_genero)
)
plt.title('Clientes que hicieron Churn por Género\n(% y cantidad)')
plt.axis('equal')  # círculo perfecto
plt.tight_layout()
plt.show()

# %%
#grafico de torta con la evasión por tipo de contrato
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar clientes que hicieron churn
df_churn = df[df['Churn'] == 'yes']  # Asegúrate de que esté en minúsculas si hiciste limpieza

# Contar tipo de contrato entre los que hicieron churn
churn_por_contrato = df_churn['account.Contract'].value_counts()

# Función para mostrar % y cantidad
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({count})'
    return my_autopct

# Gráfico de torta
plt.figure(figsize=(7,7))
plt.pie(
    churn_por_contrato,
    labels=churn_por_contrato.index,
    autopct=make_autopct(churn_por_contrato),
    startangle=90,
    colors=sns.color_palette('pastel')[0:3],
    explode=(0.05,) * len(churn_por_contrato)
)
plt.title('Distribución de Churn por Tipo de Contrato\n(% y cantidad)')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
#evasión por metodo de pago
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar los clientes que hicieron churn
df_churn = df[df['Churn'] == 'yes']  # Usa 'Yes' si no normalizaste a minúsculas

# Contar métodos de pago usados por los que hicieron churn
churn_por_pago = df_churn['account.PaymentMethod'].value_counts()

# Función para mostrar porcentaje + cantidad
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({count})'
    return my_autopct

# Gráfico de torta
plt.figure(figsize=(8,8))
plt.pie(
    churn_por_pago,
    labels=churn_por_pago.index,
    autopct=make_autopct(churn_por_pago),
    startangle=90,
    colors=sns.color_palette('pastel')[0:len(churn_por_pago)],
    explode=(0.05,) * len(churn_por_pago)
)
plt.title('Distribución de Churn por Método de Pago\n(% y cantidad)')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
#Graficar la muestra total por metodos de pago
import matplotlib.pyplot as plt
import seaborn as sns

# Contar todos los métodos de pago en el dataset completo
metodos_pago = df['account.PaymentMethod'].value_counts()

# Función para mostrar % + cantidad
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({count})'
    return my_autopct

# Gráfico de torta
plt.figure(figsize=(8,8))
plt.pie(
    metodos_pago,
    labels=metodos_pago.index,
    autopct=make_autopct(metodos_pago),
    startangle=90,
    colors=sns.color_palette('pastel')[0:len(metodos_pago)],
    explode=(0.05,) * len(metodos_pago)
)
plt.title('Distribución Total por Método de Pago\n(% y cantidad)')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
#graficos comparativos por metodo de pago - total muestra vs evasores
import matplotlib.pyplot as plt
import seaborn as sns

# Datos
metodos_pago_total = df['account.PaymentMethod'].value_counts()
metodos_pago_churn = df[df['Churn'] == 'yes']['account.PaymentMethod'].value_counts()

# Función para mostrar % + cantidad
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({count})'
    return my_autopct

# Gráficos de torta lado a lado
fig, axs = plt.subplots(1, 2, figsize=(14, 7))

# Pie chart - Todos los clientes
axs[0].pie(
    metodos_pago_total,
    labels=metodos_pago_total.index,
    autopct=make_autopct(metodos_pago_total),
    startangle=90,
    colors=sns.color_palette('pastel'),
    explode=(0.05,) * len(metodos_pago_total)
)
axs[0].set_title('Métodos de Pago - Toda la Muestra')
axs[0].axis('equal')

# Pie chart - Solo clientes con churn
axs[1].pie(
    metodos_pago_churn,
    labels=metodos_pago_churn.index,
    autopct=make_autopct(metodos_pago_churn),
    startangle=90,
    colors=sns.color_palette('pastel'),
    explode=(0.05,) * len(metodos_pago_churn)
)
axs[1].set_title('Métodos de Pago - Clientes con Churn')
axs[1].axis('equal')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Total de clientes por método de pago
total_por_pago = df['account.PaymentMethod'].value_counts()

# Clientes con churn por método de pago
churn_por_pago = df[df['Churn'] == 'yes']['account.PaymentMethod'].value_counts()

# Total general
total_clientes = len(df)
total_churn = len(df[df['Churn'] == 'yes'])

# Crear DataFrame comparativo
tabla_pago = pd.DataFrame({
    'Total Clientes': total_por_pago,
    'Clientes con Churn': churn_por_pago
})

# Calcular % del total y % del churn
tabla_pago['% en Muestra'] = tabla_pago['Total Clientes'] / total_clientes * 100
tabla_pago['% en Churn'] = tabla_pago['Clientes con Churn'] / total_churn * 100

# Calcular riesgo relativo (RR)
tabla_pago['Riesgo Relativo'] = tabla_pago['% en Churn'] / tabla_pago['% en Muestra']

# Limpiar y ordenar
tabla_pago = tabla_pago.fillna(0).sort_values('Riesgo Relativo', ascending=False)

# Redondear para presentación
tabla_pago[['% en Muestra', '% en Churn', 'Riesgo Relativo']] = tabla_pago[['% en Muestra', '% en Churn', 'Riesgo Relativo']].round(2)

# Mostrar tabla
tabla_pago
# Out:
#                            Total Clientes  Clientes con Churn  % en Muestra  \
# account.PaymentMethod
# Electronic check                     2365                1071         33.58
# Mailed check                         1612                 308         22.89
# Bank transfer (automatic)            1544                 258         21.92
# Credit card (automatic)              1522                 232         21.61
#
#                            % en Churn  Riesgo Relativo
# account.PaymentMethod
# Electronic check                57.30             1.71
# Mailed check                    16.48             0.72
# Bank transfer (automatic)       13.80             0.63
# Credit card (automatic)         12.41             0.57

# %%
#grafico de evasores por tiempo

# Función para mostrar porcentaje + cantidad
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({count})'
    return my_autopct

# Graficar pie chart, por evasores segun permanencia
plt.figure(figsize=(7,7))
plt.pie(
    churn_por_tenure,
    labels=churn_por_tenure.index,
    autopct=make_autopct(churn_por_tenure),
    startangle=90,
    colors=sns.color_palette('pastel')[0:len(churn_por_tenure)],
    explode=(0.05,) * len(churn_por_tenure)
)
plt.title('Distribución de Evasión (Churn) por Antigüedad del Cliente (Tenure)')
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-642657995> in <cell line: 0>()
#      12 plt.figure(figsize=(7,7))
#      13 plt.pie(
# ---> 14     churn_por_tenure,
#      15     labels=churn_por_tenure.index,
#      16     autopct=make_autopct(churn_por_tenure),
#
# NameError: name 'churn_por_tenure' is not defined

# %%
#pie chart para ver evasores según monto total
# Función para mostrar % y cantidad
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar solo clientes que hicieron churn
df_churn = df[df['Churn'] == 'yes'].copy()

# Eliminar nulos (por si existen)
df_churn = df_churn[df_churn['account.Charges.Total'].notna()]

# Crear rangos de gasto total
bins = [0, 500, 1500, 3000, df_churn['account.Charges.Total'].max()]
labels = ['0-500', '501-1500', '1501-3000', '3001+']
df_churn['charges_rango'] = pd.cut(df_churn['account.Charges.Total'], bins=bins, labels=labels, include_lowest=True)

# Contar churn por rango de gasto
churn_por_cargo = df_churn['charges_rango'].value_counts().sort_index()

# Función para mostrar % y cantidad
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({count})'
    return my_autopct

# Pie chart
plt.figure(figsize=(7,7))
plt.pie(
    churn_por_cargo,
    labels=churn_por_cargo.index,
    autopct=make_autopct(churn_por_cargo),
    startangle=90,
    colors=sns.color_palette('pastel')[0:len(churn_por_cargo)],
    explode=(0.05,) * len(churn_por_cargo)
)
plt.title('Distribución de Clientes que Hicieron Churn según Cargos Totales')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# #📄Informe final

# %%
Informe Final

El presente informe  tiene como objeto analisar los datos de los clientes de la empresa Telecom X, a fin de identificar las causas de la evasión de los cliente
Esto lo realizaremos a traves del proceso de ETL (Extract, Transfor, Load) del archivo Json entregado por el cliente para su analisis.

Se carga el archivo en Colab y utiliza la libreria pandas de Python para realizar la carga y se debe realizar la Normalización de los datos ya que muchas columnas
se encuentran anidadas

Se realiza limpieza y normalización de los datos, tranforman los textos a minuusculas, se convierte la columna Charges.total a Float
Se elimina los registro que tienen valor nulo o vacion en el campo Chrun, los que Complicarian el analisis

Analisis de la información recolectada:

Primer analisis indica que la evasión clientes según la información entregada corresponde al 26.5 % de los clientes, donde la proporción de hombres y mujeres
es practimente nula, 50.2 % vs 49.8%.

el siguiente analisis se realiza por tipo de contrato, donde por lejos el contrato mes a mes (Month-to-month), es el que registra mayor evasión con un 88.6%

Month-to-Month 	88.6
One-year	8.9
Two year	2.6

Se puede identificar que la menor evasión se registra en contratos de largo plazo.

Otra variable cualitativa evaluada fue el metodos de pago, donde los metodos no automaticos registran registra un 73.8% de evasión, do nde en el universo de clientes los metodos automaticos solo
significan un 43.5% de los clientes


Recomendaciones:

- Hacer ofertas y promociones a los contratos de corto plazo, para fomentar las permanecia de estos cliente
- Incentivar el uso de formas de pago automaticas
- Chequear en forma permanente la evolución de las variables anterioriore a fin
